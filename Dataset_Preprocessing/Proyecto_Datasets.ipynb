# %% [markdown]
# Importar librerias

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import pandas as pd
import os
import glob
from datasets import load_dataset

# %%
def load_file_dataframe(lang_1, lang_2, fp_lang_1, fp_lang_2):
  path = os.getcwd()

  df = pd.DataFrame(columns=["translation"])

  file_path_1 = os.path.join(path, fp_lang_1)
  file_path_2 = os.path.join(path, fp_lang_2)

  with open(file_path_1, 'r', errors='ignore') as file_1:
    with open(file_path_2, 'r', errors='ignore') as file_2:
      lines1 = file_1.read().splitlines()
      lines2 = file_2.read().splitlines()
      for i in range(len(lines1)):
        translation = {
            lang_1: lines1[i],
            lang_2: lines2[i]
        }
        new_r = {
            "translation": translation
        }
        df.loc[len(df)] = new_r

  return df

# %% [markdown]
# # Wayuu

# %%
df_wayuu_spa = load_file_dataframe("wy", "es", "Genesis1-1_WAY.txt", "Genesis1-1_ESP.txt")
df_wayuu_spa.index.name="id"
df_wayuu_spa.head()
# Out:
#                                           translation
# id
# 0   {'wy': 'Paala sümaiwa, nu’t tai wa’aya Malei w...
# 1   {'wy': 'maa’inyatuuisü tü mmakat sümaa manoukt...
# 2   {'wy': '“Anakaja warattuuliraa sümüle”, nümaka...
# 3   {'wy': 'Je süka eeitpain warattuui, talatüshi ...
# 4   {'wy': 'Je tü warattuuliikat, ni’itaain “ka’in...

# %%
df_wayuu_spa_tmp = load_file_dataframe("wy", "es", "Ley1502_WAY.txt", "Ley1502_ESP.txt")
df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)
# Out:
# <ipython-input-6-e962c73ec878>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)

# %%
df_wayuu_spa_tmp = load_file_dataframe("wy", "es", "Manglares_WAY.txt", "Manglares_ESP.txt")
df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)
# Out:
# <ipython-input-7-05fb1f186709>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)

# %%
df_wayuu_spa_tmp = load_file_dataframe("wy", "es", "tatoeba.TC.guc_train", "tatoeba.TC.esp_train")
df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)
# Out:
# <ipython-input-8-2590d053b969>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)

# %%
df_wayuu_spa_tmp = load_file_dataframe("wy", "es", "tatoeba.TC.guc_test", "tatoeba.TC.esp_test")
df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)
# Out:
# <ipython-input-9-b2fac9ac5185>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)

# %%
df_wayuu_spa_tmp = load_file_dataframe("wy", "es", "tatoeba.TC.guc_val", "tatoeba.TC.esp_val")
df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)
# Out:
# <ipython-input-10-ff1f0117aac0>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)

# %%
df_wayuu_spa_tmp = load_file_dataframe("wy", "es", "New_testament_guc.txt", "New_testament_spa.txt")
df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)
# Out:
# <ipython-input-11-1beecceeadef>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wayuu_spa = df_wayuu_spa.append(df_wayuu_spa_tmp)

# %%
df_wayuu_spa.sample(10)
# Out:
#                                              translation
# 28861  {'wy': 'anashaatasü aʼyatawaa nümüin Jeʼwaa .'...
# 32173  {'wy': 'talatashaatasü naaʼin Satanaa müleka n...
# 29703  {'wy': 'nnojoipejeʼe neʼe aküjüin nia pütchi ,...
# 27646  {'wy': 'nümakalaka nüchikuaʼa : " Oʼotoweechi ...
# 1129   {'wy': 'akatsüinraasü nanoula naya anoujashiik...
# 13245  {'wy': '¿ jamüsü sülanaʼaleeka tü naapakat Jeʼ...
# 9791   {'wy': '¿ jarat tü nuʼwayuuseinjatkat chi anne...
# 15082  {'wy': '¿ jamüsü sukuwaʼipa nutuma ? süchikije...
# 16770  {'wy': '( paashajeʼera tü pütchikat 6 sünainmü...
# 2914   {'wy': ' OuktÃ¼sÃ¼ sÃ¼seêeruêuweematapÃ¼na...

# %%
df_wayuu_spa.index.name="id"
df_wayuu_spa.to_csv("Wayuu_Spa.csv")
dataset = load_dataset("csv", data_files="Wayuu_Spa.csv")
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset.push_to_hub("wayuu_spa")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/47 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/314 [00:00<?, ?B/s]

# %% [markdown]
# # Nasa Yuwe

# %%
df_nasa_spa = load_file_dataframe("ny", "es", "Lucas1_PAEZ.txt", "Lucas1_ESP.txt")
df_nasa_spa.head()
# Out:
#                                          translation
# 0  {'ny': 'Teofiloꞌs neeweꞌwena fiꞌjni', 'es': 'P...
# 1  {'ny': 'Andy namicu Teófilo, indyaꞌs cjiyuꞌjna...
# 2                               {'ny': '', 'es': ''}
# 3  {'ny': 'Juan Bautista upywaꞌjaꞌs ptaꞌshni', 'e...
# 4  {'ny': 'Judea quiwete neꞌjueꞌsh Herodes ensuꞌ,...

# %%
df_nasa_spa_tmp = load_file_dataframe("ny", "es", "Mateo_NASA.txt", "Mateo_SPA.txt")
df_nasa_spa = df_nasa_spa.append(df_nasa_spa_tmp)
# Out:
# <ipython-input-16-5809766e7873>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasa_spa = df_nasa_spa.append(df_nasa_spa_tmp)

# %%
df_nasa_spa_tmp = load_file_dataframe("ny", "es", "LeyendoNasa_PAEZ.txt", "LeyendoNasa_ESP.txt")
df_nasa_spa = df_nasa_spa.append(df_nasa_spa_tmp)
# Out:
# <ipython-input-17-be14dc62d639>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasa_spa = df_nasa_spa.append(df_nasa_spa_tmp)

# %%
df_nasa_spa_tmp = load_file_dataframe("ny", "es", "New_testament_nasa.txt", "New_testament_spa_nasa.txt")
df_nasa_spa = df_nasa_spa.append(df_nasa_spa_tmp)
# Out:
# <ipython-input-18-f4a18444ebc4>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasa_spa = df_nasa_spa.append(df_nasa_spa_tmp)

# %%
df_nasa_spa.sample(10)
# Out:
#                                             translation
# 874   {'ny': ' TyÃ£a e'suyÃ£'jty vite cna'sawe'sh cÅ...
# 4522  {'ny': ' Atsa' tyÃ£'wáº½ nwáº½ese'jwa'jmeea's ...
# 3701  {'ny': ' TyÃ£awe'sha' teech ente' Dyusna selpi...
# 1192  {'ny': ' Jesusa' ech luucu vit-sa's we'werra':...
# 2093  {'ny': ' Neya' nchi'ca's atseyajcyna fi'nzena....
# 4903  {'ny': ' Yacjtjáº½'jwe'sh, luuch le'chcuáº½ na...
# 4592  {'ny': ' TyÃ£a pa'gatey cue'sh Ä©tyi fi'nzeni ...
# 436   {'ny': ' ipy walate acjcajn. Cyteea' seena' yu...
# 4931  {'ny': ' Nmejte' andynava vyaac, andya' en Ã£j...
# 6952  {'ny': 'TyÃ£a e'su' Dyus angel cielujÅ© quÄ©ja...

# %%
df_nasa_spa.index.name="id"
df_nasa_spa.to_csv("Nasa_Spa.csv")
dataset = load_dataset("csv", data_files="Nasa_Spa.csv")
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset.push_to_hub("nasa_spa")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/308 [00:00<?, ?B/s]
